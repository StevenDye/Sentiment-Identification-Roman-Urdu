# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import seaborn as sns
from data_prep import (df, train_df, test_df)
# from stopwords import STOPWORDS
from visualizations import meta_feature_distribution
# Out:
# /Users/stevedye/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/stevedye/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /Users/stevedye/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
df.head()
# Out:
#                                                 text sentiment  word_count  \
# 0  sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive          25
# 1                                          sahi bt h  Positive           3
# 2                                        kya bt hai,  Positive           3
# 3                                         wah je wah  Positive           3
# 4                               are wha kaya bat hai  Positive           5
#
#    unique_word_count  stop_word_count  mean_word_length  char_count
# 0                 21                6          2.920000          97
# 1                  3                0          2.333333           9
# 2                  3                1          3.000000          11
# 3                  2                0          2.666667          10
# 4                  5                1          3.200000          20

# %%
train_df.head()
# Out:
#                                                 text  word_count  \
# 0  maine tou tumhein pehlay din hi fortune teller...          14
# 1                                                              0
# 2      ya allah ham sab ke duain kabool karna ameen            9
# 3                                   mula karam keryn           3
# 4   is tarah inho ne sabit kiya ke won a sirf mat...          14
#
#    unique_word_count  stop_word_count  mean_word_length  char_count  sentiment
# 0                 14                5          4.142857          71          1
# 1                  0                0          0.000000           2          1
# 2                  9                2          4.000000          45          2
# 3                  3                0          4.666667          16          1
# 4                 14                2          3.857143          69          2

# %%
test_df.head()
# Out:
#                                                 text  word_count  \
# 0   us auhdey par reh kar inho ne karachi ki tara...          17
# 1                   buzdilun se kya gilah pakistanyu           5
# 2                              aao mil k krty hn phr           6
# 3  in ki qawwali
#   dam mast qalandar mast mast
# ...          10
# 4                           bht awla mgr vote k lie            6
#
#    unique_word_count  stop_word_count  mean_word_length  char_count  sentiment
# 0                 17                8          3.941176          84          2
# 1                  5                2          5.600000          32          0
# 2                  6                2          2.666667          21          1
# 3                  8                2          4.400000          59          1
# 4                  6                0          3.000000          24          2

# %% [markdown]
# 2 is postive, 1 is nuetral, 0 is negative

# %%
df['sentiment'].value_counts()
# Out:
# Neutral     8928
# Positive    6013
# Negative    5287
# Name: sentiment, dtype: int64

# %%
meta_feature_distribution()
