# %%
from src.data_prep import EDA_df, EDA_df_train, EDA_df_test, art_freqdist_50
from src.visualizations import meta_feature_distribution
# Out:
# /Users/stevedye/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
EDA_df.head()
# Out:
#                                                 text sentiment  word_count  \
# 0  Sai kha ya her kisi kay bus ki bat nhi hai lak...  Positive          25
# 1                                          sahi bt h  Positive           3
# 2                                        Kya bt hai,  Positive           3
# 3                                         Wah je wah  Positive           3
# 4                               Are wha kaya bat hai  Positive           5
#
#    unique_word_count  stop_word_count  mean_word_length  char_count
# 0                 22                6          2.920000          97
# 1                  3                0          2.333333           9
# 2                  3                1          3.000000          11
# 3                  3                0          2.666667          10
# 4                  5                1          3.200000          20

# %% [markdown]
# 2 is postive, 1 is nuetral, 0 is negative

# %%
EDA_df['sentiment'].value_counts()
# Out:
# Neutral     8585
# Positive    5852
# Negative    5245
# Name: sentiment, dtype: int64

# %%
art_freqdist_50
# Out:
# [('ke', 3892),
#  ('mein', 3198),
#  ('k', 2075),
#  ('ye', 917),
#  ('e', 866),
#  ('allah', 809),
#  ('nahi', 779),
#  ('in', 758),
#  ('aik', 754),
#  ('ha', 734),
#  ('me', 732),
#  ('or', 731),
#  ('b', 658),
#  ('he', 645),
#  ('kiya', 595),
#  ('ap', 571),
#  ('kay', 532),
#  ('khan', 530),
#  ('pakistan', 527),
#  ('the', 505),
#  ('h', 482),
#  ('kia', 450),
#  ('un', 432),
#  ('sath', 413),
#  ('aap', 396),
#  ('apni', 379),
#  ('bad', 361),
#  ('tak', 338),
#  ('say', 326),
#  ('ni', 310),
#  ('per', 309),
#  ('apne', 305),
#  ('jis', 305),
#  ('jab', 293),
#  ('bhai', 291),
#  ('bohat', 283),
#  ('sab', 274),
#  ('nhi', 268),
#  ('lekin', 261),
#  ('baat', 259),
#  ('o', 256),
#  ('film', 252),
#  ('hasil', 239),
#  ('d', 236),
#  ('kisi', 233),
#  ('a', 230),
#  ('nay', 228),
#  ('rahe', 228),
#  ('bht', 218),
#  ('sirf', 216)]

# %%
meta_feature_distribution(EDA_df_train, EDA_df_test)
